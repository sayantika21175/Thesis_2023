# %%
import numpy as np
import pandas as pd

# %%
bacteria_similarity=pd.read_csv('DataSet\bacteria_similarity.csv')

# %%
bacteria_similarity.head()
# Out:
#                   Bacteria1                   Bacteria2  Distance
# 0  Enterobacter agglomerans    Enterobacter agglomerans    0.0000
# 1  Enterobacter agglomerans      Enterobacter gergoviae    0.2129
# 2  Enterobacter agglomerans     Mycobacterium fortuitum    0.2404
# 3  Enterobacter agglomerans                M. abscessus    0.2384
# 4  Enterobacter agglomerans  Staphylococcus intermedius    0.2441

# %%
bacteria_similarity_mat_withoutstrain=bacteria_similarity.pivot_table(columns='Bacteria1',index='Bacteria2',values='Distance')

# %%
bacteria_similarity_mat_withoutstrain
# Out:
# Bacteria1                              Acinetobacter baumannii  \
# Bacteria2
# Acinetobacter baumannii                                 0.0000
# Aggregatibacter actinomycetemcomitans                   0.1816
# Brucella abortus                                        0.1997
# Brucella melitensis                                     0.1977
# Burkholderia pseudomallei                               0.1759
# ...                                                        ...
# Streptococcus hemolyticus                               0.2308
# Streptococcus pneumoniae                                0.2344
# Streptococcus pyogenes                                  0.2308
# Ureaplasma urealyticum                                  0.2853
# V. cholerae                                             0.1593
#
# Bacteria1                              Aggregatibacter actinomycetemcomitans  \
# Bacteria2
# Acinetobacter baumannii                                               0.1816
# ...

# %%
bacteria_similarity_mat_withoutstrain.to_csv(r'D:\3rd_sem\thesis\dataset\Sayantika\dataset\3dataset\strain_from_sir\bacteria_similarity_matrix_with_strain.csv')
